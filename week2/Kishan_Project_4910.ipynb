# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading Train Datasets

# %%
demo = pd.read_csv('/content/Train_Demographics.csv')

# %%
demo.head()
# Out:
#   CustomerID  InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0  Cust10000          35          454776          MALE                    JD
# 1  Cust10001          36          454776          MALE                    JD
# 2  Cust10002          33          603260          MALE                    JD
# 3  Cust10003          36          474848          MALE                    JD
# 4  Cust10004          29          457942        FEMALE           High School
#
#   InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country
# 0      armed-forces         movies         56700       -48500   India
# 1      tech-support      cross-fit         70600       -48500   India
# 2      armed-forces           polo         66400       -63700   India
# 3      armed-forces           polo         47900       -73400   India
# 4   exec-managerial        dancing             0       -41500   India

# %%
demo.shape
# Out:
# (28836, 10)

# %%
claim = pd.read_csv('/content/Train_Claim.csv')

# %%
claim.head()
# Out:
#   CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0  Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1  Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2  Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3  Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4  Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0         Total Loss               Police        State7        City1
# 1         Total Loss               Police        State7        City5
# 2       Minor Damage                Other        State8        City6
# 3       Minor Damage                Other        State9        City6
# 4       Minor Damage                 Fire        State8        City6
#
#   IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0   Location 1311            17                 3              ?
# 1   Location 1311            10                 3            YES
# 2   Location 2081            22                 1            YES
# 3   Location 2081            22                 1            YES
# 4   Location 1695            10                 1             NO
#
#    BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0               1         0            ?              65501
# 1               2         1          YES              61382
# 2               2         3           NO              66755
# 3               2         3           NO              66243
# 4               2         1          YES              53544
#
#    AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage
# 0                13417                   6071                  46013
# 1                15560                   5919                  39903
# 2                11630                  11630                  43495
# 3                12003                  12003                  42237
# 4                 8829                   7234                  37481

# %%
claim.shape
# Out:
# (28836, 19)

# %%
policy = pd.read_csv('/content/Train_Policy.csv')

# %%
policy.head()
# Out:
#    InsurancePolicyNumber  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0                 110122                    328           2014-10-17
# 1                 110125                    256           1990-05-25
# 2                 110126                    228           2014-06-06
# 3                 110127                    256           2006-10-12
# 4                 110128                    137           2000-06-04
#
#   InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0               State3                    250/500               1000
# 1               State1                    250/500               2000
# 2               State1                   500/1000               1000
# 3               State3                    250/500               1000
# 4               State2                    250/500               1000
#
#    PolicyAnnualPremium  UmbrellaLimit InsuredRelationship CustomerID
# 0              1406.91              0             husband   Cust1001
# 1              1415.74        6000000           unmarried   Cust1004
# 2              1583.91        6000000           unmarried   Cust1005
# 3              1351.10              0           unmarried   Cust1006
# 4              1333.35              0             husband   Cust1007

# %%
policy.shape
# Out:
# (28836, 10)

# %%
vec = pd.read_csv('/content/Train_Vehicle.csv')

# %%
vec.head()
# Out:
#   CustomerID VehicleAttribute VehicleAttributeDetails
# 0  Cust20179        VehicleID             Vehicle8898
# 1  Cust21384     VehicleModel                  Malibu
# 2  Cust33335      VehicleMake                  Toyota
# 3  Cust27118     VehicleModel                    Neon
# 4  Cust13038        VehicleID            Vehicle30212

# %%
vec = vec.set_index(['CustomerID','VehicleAttribute'], drop=True).unstack('VehicleAttribute')

# %%
vec.shape
# Out:
# (28836, 4)

# %%
fraud = pd.read_csv('/content/Traindata_with_Target.csv')

# %%
fraud.head()
# Out:
#   CustomerID ReportedFraud
# 0  Cust20065             N
# 1  Cust37589             N
# 2  Cust24312             N
# 3   Cust5493             Y
# 4   Cust7704             Y

# %%
fraud.shape
# Out:
# (28836, 2)

# %% [markdown]
# # Mergeing Datasets

# %%
# merge the datasets on a common variable
dc_df = pd.merge(demo,claim, on='CustomerID')

# %%
pv_df = pd.merge(policy,vec, on='CustomerID')
# Out:
# <ipython-input-19-6bfcc25a1a3d>:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   pv_df = pd.merge(policy,vec, on='CustomerID')

# %%
fd_df = pd.merge(dc_df,pv_df,on='CustomerID' )

# %%
train_df =  pd.merge(fd_df,fraud,on='CustomerID' )

# %%
train_df.columns
# Out:
# Index([                               'CustomerID',
#                                       'InsuredAge',
#                                   'InsuredZipCode',
#                                    'InsuredGender',
#                            'InsuredEducationLevel',
#                                'InsuredOccupation',
#                                   'InsuredHobbies',
#                                     'CapitalGains',
#                                      'CapitalLoss',
#                                          'Country',
#                                   'DateOfIncident',
#                                   'TypeOfIncident',
#                                 'TypeOfCollission',
#                               'SeverityOfIncident',
#                             'AuthoritiesContacted',
#                                    'IncidentState',
#                                     'IncidentCity',
#                                  'IncidentAddress',
#                                     'IncidentTime',
#                                 'NumberOfVehicles',
#                                   'PropertyDamage',
#                                   'BodilyInjuries',
#                                        'Witnesses',
#                                     'PoliceReport',
#                               'AmountOfTotalClaim',
#                              'AmountOfInjuryClaim',
#                            'AmountOfPropertyClaim',
#                            'AmountOfVehicleDamage',
#                            'InsurancePolicyNumber',
#                            'CustomerLoyaltyPeriod',
#                             'DateOfPolicyCoverage',
#                             'InsurancePolicyState',
#                       'Policy_CombinedSingleLimit',
#                                'Policy_Deductible',
#                              'PolicyAnnualPremium',
#                                    'UmbrellaLimit',
#                              'InsuredRelationship',
#           ('VehicleAttributeDetails', 'VehicleID'),
#         ('VehicleAttributeDetails', 'VehicleMake'),
#        ('VehicleAttributeDetails', 'VehicleModel'),
#          ('VehicleAttributeDetails', 'VehicleYOM'),
#                                    'ReportedFraud'],
#       dtype='object')

# %%
customer_ids = train_df["CustomerID"] # store the "CustomerID" column in a separate variable
train_df.drop("CustomerID", axis=1, inplace=True) # drop the "CustomerID" column from the "test_df" DataFrame

# %%
train_df.to_csv('Train_df',index=False)

# %% [markdown]
# ##  2.1 Preprocessing Merged Data

# %%
trained_df = pd.read_csv('/content/Train_df')

# %%
trained_df.head()
# Out:
#    InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0          35          454776          MALE                    JD
# 1          36          454776          MALE                    JD
# 2          33          603260          MALE                    JD
# 3          36          474848          MALE                    JD
# 4          29          457942        FEMALE           High School
#
#   InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 0      armed-forces         movies         56700       -48500   India
# 1      tech-support      cross-fit         70600       -48500   India
# 2      armed-forces           polo         66400       -63700   India
# 3      armed-forces           polo         47900       -73400   India
# 4   exec-managerial        dancing             0       -41500   India
#
#   DateOfIncident  ... Policy_CombinedSingleLimit Policy_Deductible  \
# 0     2015-02-03  ...                    100/300              1000
# 1     2015-02-02  ...                    100/300              1000
# 2     2015-01-15  ...                   500/1000               617
# 3     2015-01-19  ...                   500/1000               722
# 4     2015-01-09  ...                    100/300               500
#
#   PolicyAnnualPremium UmbrellaLimit InsuredRelationship  \
# 0             1632.73             0       not-in-family
# 1             1255.19             0       not-in-family
# 2             1373.38             0                wife
# 3             1337.60             0           own-child
# 4             1353.73       4279863           unmarried
#
#   ('VehicleAttributeDetails', 'VehicleID')  \
# 0                             Vehicle26917
# 1                             Vehicle15893
# 2                              Vehicle5152
# 3                             Vehicle37363
# 4                             Vehicle28633
#
#   ('VehicleAttributeDetails', 'VehicleMake')  \
# 0                                       Audi
# 1                                       Audi
# 2                                 Volkswagen
# 3                                 Volkswagen
# 4                                     Toyota
#
#    ('VehicleAttributeDetails', 'VehicleModel')  \
# 0                                           A5
# 1                                           A5
# 2                                        Jetta
# 3                                        Jetta
# 4                                          CRV
#
#    ('VehicleAttributeDetails', 'VehicleYOM') ReportedFraud
# 0                                       2008             N
# 1                                       2006             N
# 2                                       1999             N
# 3                                       2003             N
# 4                                       2010             N
#
# [5 rows x 41 columns]

# %%
trained_df.tail()
# Out:
#        InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 28831          46          600561          MALE               Masters
# 28832          44          439304          MALE               Masters
# 28833          53          460722          MALE                   PhD
# 28834          53          472634          MALE             Associate
# 28835          36          450730        FEMALE                   PhD
#
#        InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country  \
# 28831    protective-serv       sleeping             0            0   India
# 28832       adm-clerical        dancing             0       -28800   India
# 28833   transport-moving   base-jumping         63100       -43800   India
# 28834   transport-moving      skydiving         67400       -43800   India
# 28835  handlers-cleaners   base-jumping         46400       -74300   India
#
#       DateOfIncident  ... Policy_CombinedSingleLimit Policy_Deductible  \
# 28831     2015-01-24  ...                   500/1000               655
# 28832     2015-02-09  ...                    100/300              1089
# 28833     2015-01-28  ...                    250/500               787
# 28834     2015-01-28  ...                    250/500               780
# 28835     2015-01-13  ...                   500/1000              2000
#
#       PolicyAnnualPremium UmbrellaLimit InsuredRelationship  \
# 28831             1276.01             0           unmarried
# 28832             1273.38             0           unmarried
# 28833             1380.92       3448735           own-child
# 28834             1389.29       3364301       not-in-family
# 28835              928.43       2909175             husband
#
#       ('VehicleAttributeDetails', 'VehicleID')  \
# 28831                             Vehicle13568
# 28832                             Vehicle19810
# 28833                              Vehicle3339
# 28834                             Vehicle10240
# 28835                             Vehicle39163
#
#       ('VehicleAttributeDetails', 'VehicleMake')  \
# 28831                                     Suburu
# 28832                                       Jeep
# 28833                                     Suburu
# 28834                                     Suburu
# 28835                                     Suburu
#
#        ('VehicleAttributeDetails', 'VehicleModel')  \
# 28831                                      Impreza
# 28832                                     Wrangler
# 28833                                       Legacy
# 28834                                    Forrestor
# 28835                                         E400
#
#        ('VehicleAttributeDetails', 'VehicleYOM') ReportedFraud
# 28831                                       2007             N
# 28832                                       2003             N
# 28833                                       2004             N
# 28834                                       2004             N
# 28835                                       2007             N
#
# [5 rows x 41 columns]

# %%
trained_df.shape
# Out:
# (28836, 41)

# %%
trained_df.describe()
# Out:
#          InsuredAge  InsuredZipCode   CapitalGains    CapitalLoss  \
# count  28836.000000    28836.000000   28836.000000   28836.000000
# mean      38.815370   502436.579068   23066.569566  -24940.612429
# std        7.996377    72250.868871   27637.813724   27913.209608
# min       19.000000   430104.000000       0.000000 -111100.000000
# 25%       33.000000   448603.000000       0.000000  -50000.000000
# 50%       38.000000   466691.000000       0.000000       0.000000
# 75%       44.000000   603848.000000   49000.000000       0.000000
# max       64.000000   620962.000000  100500.000000       0.000000
#
#        IncidentTime  NumberOfVehicles  BodilyInjuries  AmountOfInjuryClaim  \
# count  28836.000000      28836.000000    28836.000000         28836.000000
# mean      11.746047          1.823207        0.985782          7337.118428
# std        6.170069          0.980099        0.784764          4427.638593
# min       -5.000000          1.000000        0.000000             0.000000
# 25%        6.000000          1.000000        0.000000          4743.750000
# 50%       12.000000          1.000000        1.000000          7147.000000
# 75%       17.000000          3.000000        2.000000         10571.250000
# max       23.000000          4.000000        2.000000         21450.000000
#
#        AmountOfPropertyClaim  AmountOfVehicleDamage  InsurancePolicyNumber  \
# count           28836.000000           28836.000000           28836.000000
# mean             7283.870197           37687.129387          129312.517097
# std              4375.842738           17977.048232           11114.060267
# min                 0.000000             109.000000          110122.000000
# 25%              4862.000000           32193.250000          119698.750000
# 50%              7051.000000           42457.500000          129278.500000
# 75%             10327.000000           49535.750000          138933.250000
# max             23670.000000           79560.000000          148619.000000
#
#        CustomerLoyaltyPeriod  Policy_Deductible  PolicyAnnualPremium  \
# count           28836.000000       28836.000000         28836.000000
# mean              203.067867        1114.282529          1255.528382
# std                99.932951         546.632816           223.013899
# min                 1.000000         500.000000            -1.000000
# 25%               126.000000         622.000000          1122.007500
# 50%               199.000000        1000.000000          1265.205000
# 75%               267.000000        1627.000000          1396.605000
# max               479.000000        2000.000000          2047.590000
#
#        UmbrellaLimit  ('VehicleAttributeDetails', 'VehicleYOM')
# count   2.883600e+04                               28836.000000
# mean    9.836680e+05                                2005.093113
# std     1.969282e+06                                   5.309956
# min    -1.000000e+06                                1995.000000
# 25%     0.000000e+00                                2001.000000
# 50%     0.000000e+00                                2005.000000
# 75%     4.859610e+05                                2010.000000
# max     1.000000e+07                                2015.000000

# %%
trained_df.columns
# Out:
# Index(['InsuredAge', 'InsuredZipCode', 'InsuredGender',
#        'InsuredEducationLevel', 'InsuredOccupation', 'InsuredHobbies',
#        'CapitalGains', 'CapitalLoss', 'Country', 'DateOfIncident',
#        'TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident',
#        'AuthoritiesContacted', 'IncidentState', 'IncidentCity',
#        'IncidentAddress', 'IncidentTime', 'NumberOfVehicles', 'PropertyDamage',
#        'BodilyInjuries', 'Witnesses', 'PoliceReport', 'AmountOfTotalClaim',
#        'AmountOfInjuryClaim', 'AmountOfPropertyClaim', 'AmountOfVehicleDamage',
#        'InsurancePolicyNumber', 'CustomerLoyaltyPeriod',
#        'DateOfPolicyCoverage', 'InsurancePolicyState',
#        'Policy_CombinedSingleLimit', 'Policy_Deductible',
#        'PolicyAnnualPremium', 'UmbrellaLimit', 'InsuredRelationship',
#        '('VehicleAttributeDetails', 'VehicleID')',
#        '('VehicleAttributeDetails', 'VehicleMake')',
#        '('VehicleAttributeDetails', 'VehicleModel')',
#        '('VehicleAttributeDetails', 'VehicleYOM')', 'ReportedFraud'],
#       dtype='object')

# %%
# Define a list of special missing value representations
special_missing_values = ["?", "MISSINGVAL", "NA", "-1", "-5", "MISSINGVALUE", "MISSEDDATA", "???"]

# Replace all instances of special missing values with NaN
trained_df.replace(special_missing_values, np.nan, inplace=True)

# Count the number of missing values in each column
missing_values_count = trained_df.isna().sum()

# Calculate the percentage of missing values in each column
percent_missing = (missing_values_count / len(trained_df)) * 100

# Create a new DataFrame to store the missing value information
missing_info = pd.DataFrame({
    "Total Missing": missing_values_count,
    "Percent Missing": percent_missing
})

print("Missing Value Information:")
print(missing_info)
# Out:
# Missing Value Information:
#                                              Total Missing  Percent Missing
# InsuredAge                                               0         0.000000
# InsuredZipCode                                           0         0.000000
# InsuredGender                                           30         0.104037
# InsuredEducationLevel                                    0         0.000000
# InsuredOccupation                                        0         0.000000
# InsuredHobbies                                           0         0.000000
# CapitalGains                                             0         0.000000
# CapitalLoss                                              0         0.000000
# Country                                                  2         0.006936
# DateOfIncident                                           0         0.000000
# TypeOfIncident                                           0         0.000000
# TypeOfCollission                                      5162        17.901235
# SeverityOfIncident                                       0         0.000000
# AuthoritiesContacted                                     0         0.000000
# IncidentState                                            0         0.000000
# IncidentCity                                             0         0.000000
# IncidentAddress                                          0         0.000000
# IncidentTime                                             0         0.000000
# NumberOfVehicles                                         0         0.000000
# PropertyDamage                                       10459        36.270634
# BodilyInjuries                                           0         0.000000
# Witnesses                                               46         0.159523
# PoliceReport                                          9805        34.002636
# AmountOfTotalClaim                                      50         0.173394
# AmountOfInjuryClaim                                      0         0.000000
# AmountOfPropertyClaim                                    0         0.000000
# AmountOfVehicleDamage                                    0         0.000000
# InsurancePolicyNumber                                    0         0.000000
# CustomerLoyaltyPeriod                                    0         0.000000
# DateOfPolicyCoverage                                     0         0.000000
# InsurancePolicyState                                     0         0.000000
# Policy_CombinedSingleLimit                               0         0.000000
# Policy_Deductible                                        0         0.000000
# PolicyAnnualPremium                                      0         0.000000
# UmbrellaLimit                                            0         0.000000
# InsuredRelationship                                      0         0.000000
# ('VehicleAttributeDetails', 'VehicleID')                 0         0.000000
# ('VehicleAttributeDetails', 'VehicleMake')              50         0.173394
# ('VehicleAttributeDetails', 'VehicleModel')              0         0.000000
# ('VehicleAttributeDetails', 'VehicleYOM')                0         0.000000
# ReportedFraud                                            0         0.000000

# %%
trained_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28836 entries, 0 to 28835
# Data columns (total 41 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   InsuredAge                                   28836 non-null  int64
#  1   InsuredZipCode                               28836 non-null  int64
#  2   InsuredGender                                28806 non-null  object
#  3   InsuredEducationLevel                        28836 non-null  object
#  4   InsuredOccupation                            28836 non-null  object
#  5   InsuredHobbies                               28836 non-null  object
#  6   CapitalGains                                 28836 non-null  int64
#  7   CapitalLoss                                  28836 non-null  int64
#  8   Country                                      28834 non-null  object
#  9   DateOfIncident                               28836 non-null  object
#  10  TypeOfIncident                               28836 non-null  object
#  11  TypeOfCollission                             23674 non-null  object
#  12  SeverityOfIncident                           28836 non-null  object
#  13  AuthoritiesContacted                         28836 non-null  object
#  14  IncidentState                                28836 non-null  object
#  15  IncidentCity                                 28836 non-null  object
#  16  IncidentAddress                              28836 non-null  object
#  17  IncidentTime                                 28836 non-null  int64
#  18  NumberOfVehicles                             28836 non-null  int64
#  19  PropertyDamage                               18377 non-null  object
#  20  BodilyInjuries                               28836 non-null  int64
#  21  Witnesses                                    28790 non-null  object
#  22  PoliceReport                                 19031 non-null  object
#  23  AmountOfTotalClaim                           28786 non-null  object
#  24  AmountOfInjuryClaim                          28836 non-null  int64
#  25  AmountOfPropertyClaim                        28836 non-null  int64
#  26  AmountOfVehicleDamage                        28836 non-null  int64
#  27  InsurancePolicyNumber                        28836 non-null  int64
#  28  CustomerLoyaltyPeriod                        28836 non-null  int64
#  29  DateOfPolicyCoverage                         28836 non-null  object
#  30  InsurancePolicyState                         28836 non-null  object
#  31  Policy_CombinedSingleLimit                   28836 non-null  object
#  32  Policy_Deductible                            28836 non-null  int64
#  33  PolicyAnnualPremium                          28836 non-null  float64
#  34  UmbrellaLimit                                28836 non-null  int64
#  35  InsuredRelationship                          28836 non-null  object
#  36  ('VehicleAttributeDetails', 'VehicleID')     28836 non-null  object
#  37  ('VehicleAttributeDetails', 'VehicleMake')   28786 non-null  object
#  38  ('VehicleAttributeDetails', 'VehicleModel')  28836 non-null  object
#  39  ('VehicleAttributeDetails', 'VehicleYOM')    28836 non-null  int64
#  40  ReportedFraud                                28836 non-null  object
# dtypes: float64(1), int64(15), object(25)
# memory usage: 9.0+ MB

# %%
# Replace missing values with the most common value for each column
for col in trained_df.columns:
    if trained_df[col].dtype == 'object':
        trained_df[col].fillna(trained_df[col].mode()[0], inplace=True)
    else:
        trained_df[col].fillna(trained_df[col].median(), inplace=True)

# %%
# Define a list of special missing value representations
special_missing_values = ["?", "MISSINGVAL", "NA", "-1", "-5", "MISSINGVALUE", "MISSEDDATA", "???"]

# Replace all instances of special missing values with NaN
trained_df.replace(special_missing_values, np.nan, inplace=True)

# Count the number of missing values in each column
missing_values_count = trained_df.isna().sum()

# Calculate the percentage of missing values in each column
percent_missing = (missing_values_count / len(trained_df)) * 100

# Create a new DataFrame to store the missing value information
missing_info = pd.DataFrame({
    "Total Missing": missing_values_count,
    "Percent Missing": percent_missing
})

print("Missing Value Information:")
print(missing_info)
# Out:
# Missing Value Information:
#                                              Total Missing  Percent Missing
# InsuredAge                                               0              0.0
# InsuredZipCode                                           0              0.0
# InsuredGender                                            0              0.0
# InsuredEducationLevel                                    0              0.0
# InsuredOccupation                                        0              0.0
# InsuredHobbies                                           0              0.0
# CapitalGains                                             0              0.0
# CapitalLoss                                              0              0.0
# Country                                                  0              0.0
# DateOfIncident                                           0              0.0
# TypeOfIncident                                           0              0.0
# TypeOfCollission                                         0              0.0
# SeverityOfIncident                                       0              0.0
# AuthoritiesContacted                                     0              0.0
# IncidentState                                            0              0.0
# IncidentCity                                             0              0.0
# IncidentAddress                                          0              0.0
# IncidentTime                                             0              0.0
# NumberOfVehicles                                         0              0.0
# PropertyDamage                                           0              0.0
# BodilyInjuries                                           0              0.0
# Witnesses                                                0              0.0
# PoliceReport                                             0              0.0
# AmountOfTotalClaim                                       0              0.0
# AmountOfInjuryClaim                                      0              0.0
# AmountOfPropertyClaim                                    0              0.0
# AmountOfVehicleDamage                                    0              0.0
# InsurancePolicyNumber                                    0              0.0
# CustomerLoyaltyPeriod                                    0              0.0
# DateOfPolicyCoverage                                     0              0.0
# InsurancePolicyState                                     0              0.0
# Policy_CombinedSingleLimit                               0              0.0
# Policy_Deductible                                        0              0.0
# PolicyAnnualPremium                                      0              0.0
# UmbrellaLimit                                            0              0.0
# InsuredRelationship                                      0              0.0
# ('VehicleAttributeDetails', 'VehicleID')                 0              0.0
# ('VehicleAttributeDetails', 'VehicleMake')               0              0.0
# ('VehicleAttributeDetails', 'VehicleModel')              0              0.0
# ('VehicleAttributeDetails', 'VehicleYOM')                0              0.0
# ReportedFraud                                            0              0.0

# %%
trained_df.dtypes
# Out:
# InsuredAge                                       int64
# InsuredZipCode                                   int64
# InsuredGender                                   object
# InsuredEducationLevel                           object
# InsuredOccupation                               object
# InsuredHobbies                                  object
# CapitalGains                                     int64
# CapitalLoss                                      int64
# Country                                         object
# DateOfIncident                                  object
# TypeOfIncident                                  object
# TypeOfCollission                                object
# SeverityOfIncident                              object
# AuthoritiesContacted                            object
# IncidentState                                   object
# IncidentCity                                    object
# IncidentAddress                                 object
# IncidentTime                                     int64
# NumberOfVehicles                                 int64
# PropertyDamage                                  object
# BodilyInjuries                                   int64
# Witnesses                                       object
# PoliceReport                                    object
# AmountOfTotalClaim                              object
# AmountOfInjuryClaim                              int64
# AmountOfPropertyClaim                            int64
# AmountOfVehicleDamage                            int64
# InsurancePolicyNumber                            int64
# CustomerLoyaltyPeriod                            int64
# DateOfPolicyCoverage                            object
# InsurancePolicyState                            object
# Policy_CombinedSingleLimit                      object
# Policy_Deductible                                int64
# PolicyAnnualPremium                            float64
# UmbrellaLimit                                    int64
# InsuredRelationship                             object
# ('VehicleAttributeDetails', 'VehicleID')        object
# ('VehicleAttributeDetails', 'VehicleMake')      object
# ('VehicleAttributeDetails', 'VehicleModel')     object
# ('VehicleAttributeDetails', 'VehicleYOM')        int64
# ReportedFraud                                   object
# dtype: object

# %%
numerical_cols = trained_df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = trained_df.select_dtypes(include='object').columns.tolist()

print("Numerical columns:")
for col in numerical_cols:
    print(f"{col} ({trained_df[col].dtype})")

print("\nCategorical columns:")
for col in categorical_cols:
    print(f"{col} ({trained_df[col].dtype})")
# Out:
# Numerical columns:
# InsuredAge (int64)
# InsuredZipCode (int64)
# CapitalGains (int64)
# CapitalLoss (int64)
# IncidentTime (int64)
# NumberOfVehicles (int64)
# BodilyInjuries (int64)
# AmountOfInjuryClaim (int64)
# AmountOfPropertyClaim (int64)
# AmountOfVehicleDamage (int64)
# InsurancePolicyNumber (int64)
# CustomerLoyaltyPeriod (int64)
# Policy_Deductible (int64)
# PolicyAnnualPremium (float64)
# UmbrellaLimit (int64)
# ('VehicleAttributeDetails', 'VehicleYOM') (int64)
#
# Categorical columns:
# InsuredGender (object)
# InsuredEducationLevel (object)
# InsuredOccupation (object)
# InsuredHobbies (object)
# Country (object)
# DateOfIncident (object)
# TypeOfIncident (object)
# TypeOfCollission (object)
# SeverityOfIncident (object)
# AuthoritiesContacted (object)
# IncidentState (object)
# IncidentCity (object)
# IncidentAddress (object)
# PropertyDamage (object)
# Witnesses (object)
# PoliceReport (object)
# AmountOfTotalClaim (object)
# DateOfPolicyCoverage (object)
# InsurancePolicyState (object)
# Policy_CombinedSingleLimit (object)
# InsuredRelationship (object)
# ('VehicleAttributeDetails', 'VehicleID') (object)
# ('VehicleAttributeDetails', 'VehicleMake') (object)
# ('VehicleAttributeDetails', 'VehicleModel') (object)
# ReportedFraud (object)

# %%
# Select categorical columns (object data type)
cat_cols = trained_df.select_dtypes(include=["object"])

# Loop through each categorical column and print unique values
for col in cat_cols:
    print(f"Unique values for column '{col}':")
    print(trained_df[col].unique())
    print()
# Out:
# Unique values for column 'InsuredGender':
# ['MALE' 'FEMALE']
#
# Unique values for column 'InsuredEducationLevel':
# ['JD' 'High School' 'Masters' 'MD' 'Associate' 'College' 'PhD']
#
# Unique values for column 'InsuredOccupation':
# ['armed-forces' 'tech-support' 'exec-managerial' 'adm-clerical'
#  'handlers-cleaners' 'craft-repair' 'prof-specialty' 'other-service'
#  'priv-house-serv' 'protective-serv' 'farming-fishing' 'sales'
#  'transport-moving' 'machine-op-inspct']
#
# Unique values for column 'InsuredHobbies':
# ['movies' 'cross-fit' 'polo' 'dancing' 'sleeping' 'camping' 'golf'
#  'paintball' 'base-jumping' 'yachting' 'basketball' 'hiking'
#  'bungie-jumping' 'exercise' 'board-games' 'reading' 'skydiving'
#  'video-games' 'kayaking' 'chess']
#
# Unique values for column 'Country':
# ['India']
#
# Unique values for column 'DateOfIncident':
# ['2015-02-03' '2015-02-02' '2015-01-15' '2015-01-19' '2015-01-09'
#  '2015-02-07' '2015-01-30' '2015-01-12' '2015-02-06' '2015-01-25'
#  '2015-02-10' '2015-02-22' '2015-02-25' '2015-01-02' '2015-02-28'
#  '2015-01-03' '2015-01-29' '2015-02-23' '2015-01-28' '2015-02-26'
#  '2015-01-27' '2015-01-16' '2015-01-17' '2015-02-04' '2015-01-05'
#  '2015-01-10' '2015-02-11' '2015-01-13' '2015-01-06' '2015-01-07'
#  '2015-02-17' '2015-02-12' '2015-02-13' '2015-01-26' '2015-02-21'
#  '2015-02-14' '2015-02-15' '2015-01-20' '2015-01-24' '2015-01-08'
#  '2015-01-11' '2015-02-09' '2015-02-27' '2015-02-24' '2015-01-18'
#  '2015-02-08' '2015-01-22' '2015-02-19' '2015-02-18' '2015-02-16'
#  '2015-01-04' '2015-02-05' '2015-01-01' '2015-01-23' '2015-01-21'
#  '2015-01-14' '2015-02-20' '2015-01-31' '2015-03-06' '2015-03-01'
#  '2015-03-04' '2015-03-03' '2015-03-02' '2015-02-01' '2015-03-05'
#  '2015-03-09' '2015-03-11' '2015-03-07' '2015-03-08' '2015-03-12'
#  '2015-03-10' '2015-03-14']
#
# Unique values for column 'TypeOfIncident':
# ['Multi-vehicle Collision' 'Single Vehicle Collision' 'Parked Car'
#  'Vehicle Theft']
#
# Unique values for column 'TypeOfCollission':
# ['Side Collision' 'Rear Collision' 'Front Collision']
#
# Unique values for column 'SeverityOfIncident':
# ['Total Loss' 'Minor Damage' 'Major Damage' 'Trivial Damage']
#
# Unique values for column 'AuthoritiesContacted':
# ['Police' 'Other' 'Fire' 'Ambulance' 'None']
#
# Unique values for column 'IncidentState':
# ['State7' 'State8' 'State9' 'State5' 'State6' 'State4' 'State3']
#
# Unique values for column 'IncidentCity':
# ['City1' 'City5' 'City6' 'City4' 'City3' 'City2' 'City7']
#
# Unique values for column 'IncidentAddress':
# ['Location 1311' 'Location 2081' 'Location 1695' 'Location 1440'
#  'Location 1521' 'Location 1596' 'Location 2002' 'Location 1341'
#  'Location 1799' 'Location 2030' 'Location 1677' 'Location 1963'
#  'Location 1449' 'Location 1580' 'Location 1167' 'Location 1261'
#  'Location 1793' 'Location 1112' 'Location 2092' 'Location 1292'
#  'Location 1024' 'Location 1426' 'Location 1359' 'Location 1228'
#  'Location 1990' 'Location 2054' 'Location 1076' 'Location 1025'
#  'Location 1372' 'Location 1629' 'Location 1060' 'Location 1189'
#  'Location 1518' 'Location 1302' 'Location 1690' 'Location 1469'
#  'Location 1593' 'Location 1231' 'Location 2051' 'Location 1362'
#  'Location 1916' 'Location 1179' 'Location 1404' 'Location 1842'
#  'Location 1834' 'Location 1986' 'Location 1943' 'Location 1345'
#  'Location 1326' 'Location 1090' 'Location 1353' 'Location 1703'
#  'Location 1863' 'Location 1517' 'Location 1838' 'Location 1966'
#  'Location 1767' 'Location 1482' 'Location 1892' 'Location 2001'
#  'Location 1620' 'Location 1320' 'Location 1807' 'Location 1104'
#  'Location 1177' 'Location 1574' 'Location 1756' 'Location 1089'
#  'Location 1942' 'Location 2078' 'Location 1523' 'Location 1858'
#  'Location 1582' 'Location 1441' 'Location 2077' 'Location 1131'
#  'Location 1935' 'Location 1460' 'Location 1524' 'Location 1773'
#  'Location 1824' 'Location 1597' 'Location 1500' 'Location 2074'
#  'Location 1330' 'Location 1286' 'Location 1958' 'Location 1346'
#  'Location 1944' 'Location 1361' 'Location 1586' 'Location 2096'
#  'Location 1573' 'Location 1655' 'Location 1498' 'Location 1409'
#  'Location 1654' 'Location 1439' 'Location 1953' 'Location 1995'
#  '1998-11-03']
#
# Unique values for column 'InsurancePolicyState':
# ['State1' 'State3' 'State2']
#
# Unique values for column 'Policy_CombinedSingleLimit':
# ['100/300' '500/1000' '250/500' '250/1000' '500/300' '500/500' '100/500'
#  '250/300' '100/1000']
#
# Unique values for column 'InsuredRelationship':
# ['not-in-family' 'wife' 'own-child' 'unmarried' 'husband' 'other-relative']
#
# Unique values for column '('VehicleAttributeDetails', 'VehicleID')':
# ['Vehicle26917' 'Vehicle15893' 'Vehicle5152' ... 'Vehicle3339'
#  'Vehicle10240' 'Vehicle39163']
#
# Unique values for column '('VehicleAttributeDetails', 'VehicleMake')':
# ['Audi' 'Volkswagen' 'Toyota' 'Mercedes' 'Suburu' 'Saab' 'Nissan' 'Ford'
#  'Accura' 'Dodge' 'Honda' 'Chevrolet' 'Jeep' 'BMW']
#
# Unique values for column '('VehicleAttributeDetails', 'VehicleModel')':
# ['A5' 'Jetta' 'CRV' 'C300' 'Passat' '92x' 'Ultima' 'Fusion' 'Impreza' '93'
#  'Highlander' 'X5' 'Accord' 'Corolla' 'Forrestor' 'F150' 'Pathfinder'
#  'Neon' 'Tahoe' 'Wrangler' 'A3' 'RSX' 'Malibu' 'E400' 'Legacy' '95'
#  'Grand Cherokee' 'Escape' 'Civic' 'Silverado' 'RAM' 'Camry' 'M5'
#  '3 Series' 'ML350' 'Maxima' 'MDX' 'X6' 'TL']
#
# Unique values for column 'ReportedFraud':
# ['N' 'Y']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Loop through all columns except the target column
for col in trained_df.drop("ReportedFraud", axis=1).select_dtypes(include=['float', 'int']).columns:
    # Create histogram for the current column with respect to the target column
    sns.histplot(data=trained_df, x=col, hue="ReportedFraud")
    plt.title(f"{col.capitalize()} Histogram with Respect to Target")
    plt.show()

    # Create box plot for the current column with respect to the target column
    sns.boxplot(data=trained_df, x="ReportedFraud", y=col)
    plt.title(f"{col.capitalize()} Box Plot with Respect to Target")
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# select categorical columns
categorical_cols = trained_df.select_dtypes(include='object').columns.tolist()

# convert the categorical columns to string data type
trained_df[categorical_cols] = trained_df[categorical_cols].astype(str)

# apply label encoding to categorical columns
encoder = LabelEncoder()
for col in categorical_cols:
    trained_df[col] = encoder.fit_transform(trained_df[col])

# %%
trained_df.dtypes
# Out:
# InsuredAge                                       int64
# InsuredZipCode                                   int64
# InsuredGender                                    int64
# InsuredEducationLevel                            int64
# InsuredOccupation                                int64
# InsuredHobbies                                   int64
# CapitalGains                                     int64
# CapitalLoss                                      int64
# Country                                          int64
# DateOfIncident                                   int64
# TypeOfIncident                                   int64
# TypeOfCollission                                 int64
# SeverityOfIncident                               int64
# AuthoritiesContacted                             int64
# IncidentState                                    int64
# IncidentCity                                     int64
# IncidentAddress                                  int64
# IncidentTime                                     int64
# NumberOfVehicles                                 int64
# PropertyDamage                                   int64
# BodilyInjuries                                   int64
# Witnesses                                        int64
# PoliceReport                                     int64
# AmountOfTotalClaim                               int64
# AmountOfInjuryClaim                              int64
# AmountOfPropertyClaim                            int64
# AmountOfVehicleDamage                            int64
# InsurancePolicyNumber                            int64
# CustomerLoyaltyPeriod                            int64
# DateOfPolicyCoverage                             int64
# InsurancePolicyState                             int64
# Policy_CombinedSingleLimit                       int64
# Policy_Deductible                                int64
# PolicyAnnualPremium                            float64
# UmbrellaLimit                                    int64
# InsuredRelationship                              int64
# ('VehicleAttributeDetails', 'VehicleID')         int64
# ('VehicleAttributeDetails', 'VehicleMake')       int64
# ('VehicleAttributeDetails', 'VehicleModel')      int64
# ('VehicleAttributeDetails', 'VehicleYOM')        int64
# ReportedFraud                                    int64
# dtype: object

# %%
numerical_cols = trained_df.select_dtypes(include=np.number).columns.tolist()
print("Numerical columns:")
for col in numerical_cols:
    print(f"{col} ({trained_df[col].dtype})")
# Out:
# Numerical columns:
# InsuredAge (int64)
# InsuredZipCode (int64)
# InsuredGender (int64)
# InsuredEducationLevel (int64)
# InsuredOccupation (int64)
# InsuredHobbies (int64)
# CapitalGains (int64)
# CapitalLoss (int64)
# Country (int64)
# DateOfIncident (int64)
# TypeOfIncident (int64)
# TypeOfCollission (int64)
# SeverityOfIncident (int64)
# AuthoritiesContacted (int64)
# IncidentState (int64)
# IncidentCity (int64)
# IncidentAddress (int64)
# IncidentTime (int64)
# NumberOfVehicles (int64)
# PropertyDamage (int64)
# BodilyInjuries (int64)
# Witnesses (int64)
# PoliceReport (int64)
# AmountOfTotalClaim (int64)
# AmountOfInjuryClaim (int64)
# AmountOfPropertyClaim (int64)
# AmountOfVehicleDamage (int64)
# InsurancePolicyNumber (int64)
# CustomerLoyaltyPeriod (int64)
# DateOfPolicyCoverage (int64)
# InsurancePolicyState (int64)
# Policy_CombinedSingleLimit (int64)
# Policy_Deductible (int64)
# PolicyAnnualPremium (float64)
# UmbrellaLimit (int64)
# InsuredRelationship (int64)
# ('VehicleAttributeDetails', 'VehicleID') (int64)
# ('VehicleAttributeDetails', 'VehicleMake') (int64)
# ('VehicleAttributeDetails', 'VehicleModel') (int64)
# ('VehicleAttributeDetails', 'VehicleYOM') (int64)
# ReportedFraud (int64)

# %%
import math

sns.set(style="ticks")
num_cols = len(trained_df.columns)
rows = 21
cols = math.ceil(num_cols/rows)
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(20, 80))

for i, col in enumerate(trained_df.columns):
    row_id = i // cols
    col_id = i % cols
    sns.boxplot(x=trained_df[col], ax=axes[row_id, col_id], orient='h')
    axes[row_id, col_id].set_xlabel(col)

plt.tight_layout()
plt.show()

# %%
# loop through each numeric column
for col in numerical_cols:
    # calculate the first quartile (Q1)
    q1 = trained_df[col].quantile(0.25)
    
    # calculate the third quartile (Q3)
    q3 = trained_df[col].quantile(0.75)
    
    # calculate the interquartile range (IQR)
    iqr = q3 - q1
    
    # calculate the lower and upper bounds for outliers
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    
    # replace outliers with the median value of the column
    trained_df[col] = np.where((trained_df[col] < lower) | (trained_df[col] > upper), trained_df[col].median(), trained_df[col])

# loop through each numeric column
for col in numerical_cols:
    # calculate the first quartile (Q1)
    q1 = trained_df[col].quantile(0.25)
    
    # calculate the third quartile (Q3)
    q3 = trained_df[col].quantile(0.75)
    
    # calculate the interquartile range (IQR)
    iqr = q3 - q1
    
    # calculate the lower and upper bounds for outliers
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    
    # identify and count the outliers
    outliers = trained_df[(trained_df[col] < lower) | (trained_df[col] > upper)]
    pct_outliers = len(outliers) / len(trained_df) * 100
    
    # print the percentage of outliers for the column
    print(f"{col} has {pct_outliers:.2f}% outliers")
# Out:
# InsuredAge has 0.00% outliers
# InsuredZipCode has 0.00% outliers
# InsuredGender has 0.00% outliers
# InsuredEducationLevel has 0.00% outliers
# InsuredOccupation has 0.00% outliers
# InsuredHobbies has 0.00% outliers
# CapitalGains has 0.00% outliers
# CapitalLoss has 0.00% outliers
# Country has 0.00% outliers
# DateOfIncident has 0.00% outliers
# TypeOfIncident has 0.00% outliers
# TypeOfCollission has 0.00% outliers
# SeverityOfIncident has 0.00% outliers
# AuthoritiesContacted has 0.00% outliers
# IncidentState has 0.00% outliers
# IncidentCity has 0.00% outliers
# IncidentAddress has 0.00% outliers
# IncidentTime has 0.00% outliers
# NumberOfVehicles has 0.00% outliers
# PropertyDamage has 0.00% outliers
# BodilyInjuries has 0.00% outliers
# Witnesses has 0.00% outliers
# PoliceReport has 0.00% outliers
# AmountOfTotalClaim has 0.00% outliers
# AmountOfInjuryClaim has 0.00% outliers
# AmountOfPropertyClaim has 0.07% outliers
# AmountOfVehicleDamage has 5.14% outliers
# InsurancePolicyNumber has 0.00% outliers
# CustomerLoyaltyPeriod has 0.00% outliers
# DateOfPolicyCoverage has 0.00% outliers
# InsurancePolicyState has 0.00% outliers
# Policy_CombinedSingleLimit has 0.00% outliers
# Policy_Deductible has 0.00% outliers
# PolicyAnnualPremium has 0.20% outliers
# UmbrellaLimit has 4.54% outliers
# InsuredRelationship has 0.00% outliers
# ('VehicleAttributeDetails', 'VehicleID') has 0.00% outliers
# ('VehicleAttributeDetails', 'VehicleMake') has 0.00% outliers
# ('VehicleAttributeDetails', 'VehicleModel') has 0.00% outliers
# ('VehicleAttributeDetails', 'VehicleYOM') has 0.00% outliers
# ReportedFraud has 0.00% outliers

# %%
trained_df.shape
# Out:
# (28836, 41)

# %%
import warnings
warnings.filterwarnings('ignore')

# Get numeric columns in the dataset
numeric_cols = trained_df.select_dtypes(include=[np.number]).columns

# Create subplots
fig, axes = plt.subplots(nrows=21, ncols=2, figsize=(10, 50))

# Iterate over each numeric column and plot its distribution
for i, col in enumerate(numeric_cols):
    sns.distplot(trained_df[col], ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title("Skewness: {:.2f} | Column: {}".format(trained_df[col].skew(), col))

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = trained_df.drop(["ReportedFraud"], axis = 1)
y = trained_df["ReportedFraud"]

sc = StandardScaler()
X_scaled = sc.fit_transform(X)
X_scaled
# Out:
# array([[-0.47100636, -0.6596655 ,  1.09126186, ..., -1.36441017,
#         -1.31136507,  0.54745044],
#        [-0.34273085, -0.6596655 ,  1.09126186, ..., -1.36441017,
#         -1.31136507,  0.17079294],
#        [-0.72755738,  1.39548729,  1.09126186, ...,  1.59522311,
#          0.0328072 , -1.14750833],
#        ...,
#        [ 1.83795284, -0.57736748,  1.09126186, ...,  1.1019509 ,
#          0.12241869, -0.20586457],
#        [ 1.83795284, -0.41249464,  1.09126186, ...,  1.1019509 ,
#         -0.41525022, -0.20586457],
#        [-0.34273085, -0.7156658 , -0.91637034, ...,  1.1019509 ,
#         -0.68408468,  0.35912169]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import f1_score

# %%
model1 = RandomForestClassifier()
model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_train = model1.predict(X_train)
y_pred_test = model1.predict(X_test)

# %%
train_accuracy = model1.score(X_train, y_train)
test_accuracy = model1.score(X_test, y_test)

print("Training accuracy:", train_accuracy)
print("Test accuracy:", test_accuracy)
# Out:
# Training accuracy: 0.999950458261085
# Test accuracy: 0.932955727661542

# %%
model2 = DecisionTreeClassifier()
model2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train2 = model2.predict(X_train)
y_pred_test2 = model2.predict(X_test)

# %%
train_accuracy2 = model2.score(X_train, y_train)
test_accuracy2 = model2.score(X_test, y_test)

print("Training accuracy:", train_accuracy2)
print("Test accuracy:", test_accuracy2)
# Out:
# Training accuracy: 1.0
# Test accuracy: 0.8749277540168766

# %%
model3 = KNeighborsClassifier()
model3.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_train3 = model3.predict(X_train)
y_pred_test3 = model3.predict(X_test)

# %%
train_accuracy3 = model3.score(X_train, y_train)
test_accuracy3 = model3.score(X_test, y_test)

print("Training accuracy:", train_accuracy3)
print("Test accuracy:", test_accuracy3)
# Out:
# Training accuracy: 0.873024523160763
# Test accuracy: 0.8209455554271182

# %%
model4 = LogisticRegression()
model4.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train4 = model4.predict(X_train)
y_pred_test4= model4.predict(X_test)

# %%
train_accuracy4 = model4.score(X_train, y_train)
test_accuracy4= model4.score(X_test, y_test)

print("Training accuracy:", train_accuracy4)
print("Test accuracy:", test_accuracy4)
# Out:
# Training accuracy: 0.7557096854099579
# Test accuracy: 0.7510114437637267

# %%
model5 = GaussianNB()
model5.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_train5 = model5.predict(X_train)
y_pred_test5= model5.predict(X_test)

# %%
train_accuracy5 = model5.score(X_train, y_train)
test_accuracy5= model5.score(X_test, y_test)

print("Training accuracy:", train_accuracy4)
print("Test accuracy:", test_accuracy4)
# Out:
# Training accuracy: 0.7557096854099579
# Test accuracy: 0.7510114437637267

# %%
import pandas as pd

model_names = ["RandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "LogisticRegression", "GaussianNB"]

# Calculate F1 scores for all models
f1_scores_train = []
f1_scores_test = []

for model in [model1, model2, model3, model4, model5]:
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    f1_scores_train.append(f1_score(y_train, y_pred_train))
    f1_scores_test.append(f1_score(y_test, y_pred_test))

# Create DataFrame to display results
results_df = pd.DataFrame({
    "Model_Name": model_names,
    "Train_F1_score": f1_scores_train,
    "Test_F1_score": f1_scores_test
})

print(results_df)
# Out:
#                Model_Name  Train_F1_score  Test_F1_score
# 0  RandomForestClassifier        0.999908       0.867701
# 1  DecisionTreeClassifier        1.000000       0.771826
# 2    KNeighborsClassifier        0.741137       0.636811
# 3      LogisticRegression        0.332476       0.328554
# 4              GaussianNB        0.589824       0.590549

# %%
import pickle

# %%
# Train 5 different models on the data
models = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    KNeighborsClassifier(),
    GaussianNB()
]

for i, model in enumerate(models):
    model.fit(X, y)
    
    # Create a pickle file for each model
    with open(f'model_{i}.pkl', 'wb') as f:
        pickle.dump(model, f)
